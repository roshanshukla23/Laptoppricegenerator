# %% [markdown]
# <a href="https://colab.research.google.com/github/roshanshukla23/Laptoppricegenerator/blob/main/laptopprice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/MATPLOTLIB/pandas/datasets/laptop_price.csv",encoding='latin')

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
sns.barplot(x=df['Company'],y=df['Price_euros'])
plt.xticks(rotation=90)
plt.show()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Product'].value_counts()
# Out:
# Product
# XPS 13                                     30
# Inspiron 3567                              29
# 250 G6                                     21
# Legion Y520-15IKBN                         19
# Vostro 3568                                19
#                                            ..
# 15-bw007nv (A10-9620P/6GB/128GB/Radeon      1
# SmartBook 130                               1
# A541NA-GO342 (N3350/4GB/500GB/Linux)        1
# 17-X047na (i3-6006U/8GB/1TB/W10)            1
# V330-15IKB (i5-8250U/4GB/500GB/FHD/W10)     1
# Name: count, Length: 618, dtype: int64

# %%
sns.displot(x=df['Inches'],kde=2)

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
(lambda x:x.split()[-1].split('x')[0])("IPS Panel Touchscreen 2400x1600")
# Out:
# '2400'

# %%
df['X_res']=df['ScreenResolution'].apply(lambda x:x.split()[-1].split('x')[0]).astype(int)

# %%
df['Y_res']=df['ScreenResolution'].apply(lambda x:x.split()[-1].split('x')[1]).astype(int)

# %%
df['X_res']
# Out:
# 0       2560
# 1       1440
# 2       1920
# 3       2880
# 4       2560
#         ...
# 1298    1920
# 1299    3200
# 1300    1366
# 1301    1366
# 1302    1366
# Name: X_res, Length: 1303, dtype: int64

# %%
df['Y_res']
# Out:
# 0       1600
# 1        900
# 2       1080
# 3       1800
# 4       1600
#         ...
# 1298    1080
# 1299    1800
# 1300     768
# 1301     768
# 1302     768
# Name: Y_res, Length: 1303, dtype: int64

# %%
df['PPI']=np.sqrt((df['X_res']**2)+(df['Y_res']**2))/df['Inches']
np.round(df['PPI'])
# Out:
# 0       227.0
# 1       128.0
# 2       141.0
# 3       221.0
# 4       227.0
#         ...
# 1298    157.0
# 1299    276.0
# 1300    112.0
# 1301    100.0
# 1302    100.0
# Name: PPI, Length: 1303, dtype: float64

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros  X_res  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69   2560
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94   1440
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00   1920
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45   2880
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60   2560
# ...                            ...         ...     ...          ...    ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00   1920
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00   3200
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00   1366
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00   1366
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00   1366
#
#       Y_res         PPI
# 0      1600  226.983005
# 1       900  127.677940
# 2      1080  141.211998
# 3      1800  220.534624
# 4      1600  226.983005
# ...     ...         ...
# 1298   1080  157.350512
# 1299   1800  276.053530
# 1300    768  111.935204
# 1301    768  100.454670
# 1302    768  100.454670
#
# [1303 rows x 16 columns]

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if "Touchscreen" in x else 0)
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if "IPS" in x else 0)

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   laptop_ID    1303 non-null   int64
#  1   Company      1303 non-null   object
#  2   Product      1303 non-null   object
#  3   TypeName     1303 non-null   object
#  4   Inches       1303 non-null   float64
#  5   Cpu          1303 non-null   object
#  6   Ram          1303 non-null   object
#  7   Memory       1303 non-null   object
#  8   Gpu          1303 non-null   object
#  9   OpSys        1303 non-null   object
#  10  Weight       1303 non-null   object
#  11  Price_euros  1303 non-null   float64
#  12  X_res        1303 non-null   int64
#  13  Y_res        1303 non-null   int64
#  14  PPI          1303 non-null   float64
#  15  Touchscreen  1303 non-null   int64
#  16  IPS          1303 non-null   int64
# dtypes: float64(3), int64(5), object(9)
# memory usage: 173.2+ KB

# %%
df['PPI']=round(((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches'],0)

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                                   Cpu   Ram  \
# 0              Ultrabook    13.3                  Intel Core i5 2.3GHz   8GB
# 1              Ultrabook    13.3                  Intel Core i5 1.8GHz   8GB
# 2               Notebook    15.6            Intel Core i5 7200U 2.5GHz   8GB
# 3              Ultrabook    15.4                  Intel Core i7 2.7GHz  16GB
# 4              Ultrabook    13.3                  Intel Core i5 3.1GHz   8GB
# ...                  ...     ...                                   ...   ...
# 1298  2 in 1 Convertible    14.0            Intel Core i7 6500U 2.5GHz   4GB
# 1299  2 in 1 Convertible    13.3            Intel Core i7 6500U 2.5GHz  16GB
# 1300            Notebook    14.0  Intel Celeron Dual Core N3050 1.6GHz   2GB
# 1301            Notebook    15.6            Intel Core i7 6500U 2.5GHz   6GB
# 1302            Notebook    15.6  Intel Celeron Dual Core N3050 1.6GHz   4GB
#
#                    Memory                           Gpu       OpSys  Weight  \
# 0               128GB SSD  Intel Iris Plus Graphics 640       macOS  1.37kg
# 1     128GB Flash Storage        Intel HD Graphics 6000       macOS  1.34kg
# 2               256GB SSD         Intel HD Graphics 620       No OS  1.86kg
# 3               512GB SSD            AMD Radeon Pro 455       macOS  1.83kg
# 4               256GB SSD  Intel Iris Plus Graphics 650       macOS  1.37kg
# ...                   ...                           ...         ...     ...
# 1298            128GB SSD         Intel HD Graphics 520  Windows 10   1.8kg
# 1299            512GB SSD         Intel HD Graphics 520  Windows 10   1.3kg
# 1300   64GB Flash Storage             Intel HD Graphics  Windows 10   1.5kg
# 1301              1TB HDD            AMD Radeon R5 M330  Windows 10  2.19kg
# 1302            500GB HDD             Intel HD Graphics  Windows 10   2.2kg
#
#       Price_euros  X_res  Y_res    PPI  Touchscreen  IPS
# 0         1339.69   2560   1600  227.0            0    1
# 1          898.94   1440    900  128.0            0    0
# 2          575.00   1920   1080  141.0            0    0
# 3         2537.45   2880   1800  221.0            0    1
# 4         1803.60   2560   1600  227.0            0    1
# ...           ...    ...    ...    ...          ...  ...
# 1298       638.00   1920   1080  157.0            1    1
# 1299      1499.00   3200   1800  276.0            1    1
# 1300       229.00   1366    768  112.0            0    0
# 1301       764.00   1366    768  100.0            0    0
# 1302       369.00   1366    768  100.0            0    0
#
# [1303 rows x 17 columns]

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName                                   Cpu   Ram  \
# 0              Ultrabook                  Intel Core i5 2.3GHz   8GB
# 1              Ultrabook                  Intel Core i5 1.8GHz   8GB
# 2               Notebook            Intel Core i5 7200U 2.5GHz   8GB
# 3              Ultrabook                  Intel Core i7 2.7GHz  16GB
# 4              Ultrabook                  Intel Core i5 3.1GHz   8GB
# ...                  ...                                   ...   ...
# 1298  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   4GB
# 1299  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz  16GB
# 1300            Notebook  Intel Celeron Dual Core N3050 1.6GHz   2GB
# 1301            Notebook            Intel Core i7 6500U 2.5GHz   6GB
# 1302            Notebook  Intel Celeron Dual Core N3050 1.6GHz   4GB
#
#                    Memory                           Gpu       OpSys  Weight  \
# 0               128GB SSD  Intel Iris Plus Graphics 640       macOS  1.37kg
# 1     128GB Flash Storage        Intel HD Graphics 6000       macOS  1.34kg
# 2               256GB SSD         Intel HD Graphics 620       No OS  1.86kg
# 3               512GB SSD            AMD Radeon Pro 455       macOS  1.83kg
# 4               256GB SSD  Intel Iris Plus Graphics 650       macOS  1.37kg
# ...                   ...                           ...         ...     ...
# 1298            128GB SSD         Intel HD Graphics 520  Windows 10   1.8kg
# 1299            512GB SSD         Intel HD Graphics 520  Windows 10   1.3kg
# 1300   64GB Flash Storage             Intel HD Graphics  Windows 10   1.5kg
# 1301              1TB HDD            AMD Radeon R5 M330  Windows 10  2.19kg
# 1302            500GB HDD             Intel HD Graphics  Windows 10   2.2kg
#
#       Price_euros    PPI  Touchscreen  IPS
# 0         1339.69  227.0            0    1
# 1          898.94  128.0            0    0
# 2          575.00  141.0            0    0
# 3         2537.45  221.0            0    1
# 4         1803.60  227.0            0    1
# ...           ...    ...          ...  ...
# 1298       638.00  157.0            1    1
# 1299      1499.00  276.0            1    1
# 1300       229.00  112.0            0    0
# 1301       764.00  100.0            0    0
# 1302       369.00  100.0            0    0
#
# [1303 rows x 14 columns]

# %%
df['Cpu']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName                 Cpu   Ram               Memory  \
# 0              Ultrabook       Intel Core i5   8GB            128GB SSD
# 1              Ultrabook       Intel Core i5   8GB  128GB Flash Storage
# 2               Notebook       Intel Core i5   8GB            256GB SSD
# 3              Ultrabook       Intel Core i7  16GB            512GB SSD
# 4              Ultrabook       Intel Core i5   8GB            256GB SSD
# ...                  ...                 ...   ...                  ...
# 1298  2 in 1 Convertible       Intel Core i7   4GB            128GB SSD
# 1299  2 in 1 Convertible       Intel Core i7  16GB            512GB SSD
# 1300            Notebook  Intel Celeron Dual   2GB   64GB Flash Storage
# 1301            Notebook       Intel Core i7   6GB              1TB HDD
# 1302            Notebook  Intel Celeron Dual   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros    PPI  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  227.0
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  128.0
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  141.0
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45  221.0
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60  227.0
# ...                            ...         ...     ...          ...    ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00  157.0
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00  276.0
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00  112.0
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00  100.0
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00  100.0
#
#       Touchscreen  IPS
# 0               0    1
# 1               0    0
# 2               0    0
# 3               0    1
# 4               0    1
# ...           ...  ...
# 1298            1    1
# 1299            1    1
# 1300            0    0
# 1301            0    0
# 1302            0    0
#
# [1303 rows x 14 columns]

# %%
def fetch_cpu_name(text):
  if text=="Intel Core i7" or text=="Intel Core i5" or text=="Intel Core i3" or "Intel Core M":
    return text
  elif text.split()[0]=='Intel':
    return " ".join(text.split()[0:2])
  else:
    return "AMD Processor"

# %%
df['Cpu']=df['Cpu'].apply(fetch_cpu_name)

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
plt.figure(figsize=(10,4))
sns.barplot(x=df['Cpu'],y=df['Price_euros'])
plt.xticks(rotation=90)

plt.show()

# %%
df['Ram'].apply(lambda x:x.replace("GB","")).astype('int')
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1298     4
# 1299    16
# 1300     2
# 1301     6
# 1302     4
# Name: Ram, Length: 1303, dtype: int64

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8GB     619
# 4GB     375
# 16GB    200
# 6GB      41
# 12GB     25
# 2GB      22
# 32GB     17
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price_euros'])
# Out:
# <Axes: xlabel='Ram', ylabel='Price_euros'>

# %%
df['Memory'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                 128GB SSD
# 1       128GB Flash Storage
# 2                 256GB SSD
# 3                 512GB SSD
# 4                 256GB SSD
#                ...
# 1298              128GB SSD
# 1299              512GB SSD
# 1300     64GB Flash Storage
# 1301                1TB HDD
# 1302              500GB HDD
# Name: Memory, Length: 1303, dtype: object>

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName                 Cpu   Ram  \
# 0              Ultrabook       Intel Core i5   8GB
# 1              Ultrabook       Intel Core i5   8GB
# 2               Notebook       Intel Core i5   8GB
# 3              Ultrabook       Intel Core i7  16GB
# 4              Ultrabook       Intel Core i5   8GB
# ...                  ...                 ...   ...
# 1298  2 in 1 Convertible       Intel Core i7   4GB
# 1299  2 in 1 Convertible       Intel Core i7  16GB
# 1300            Notebook  Intel Celeron Dual   2GB
# 1301            Notebook       Intel Core i7   6GB
# 1302            Notebook  Intel Celeron Dual   4GB
#
#                                Gpu       OpSys  Weight  Price_euros    PPI  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  227.0
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  128.0
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  141.0
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45  221.0
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60  227.0
# ...                            ...         ...     ...          ...    ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00  157.0
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00  276.0
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00  112.0
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00  100.0
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00  100.0
#
#       Touchscreen  IPS
# 0               0    1
# 1               0    0
# 2               0    0
# 3               0    1
# 4               0    1
# ...           ...  ...
# 1298            1    1
# 1299            1    1
# 1300            0    0
# 1301            0    0
# 1302            0    0
#
# [1303 rows x 13 columns]

# %%
df['Gpu'].apply(lambda x:x.split())
# Out:
# 0       [Intel, Iris, Plus, Graphics, 640]
# 1              [Intel, HD, Graphics, 6000]
# 2               [Intel, HD, Graphics, 620]
# 3                  [AMD, Radeon, Pro, 455]
# 4       [Intel, Iris, Plus, Graphics, 650]
#                        ...
# 1298            [Intel, HD, Graphics, 520]
# 1299            [Intel, HD, Graphics, 520]
# 1300                 [Intel, HD, Graphics]
# 1301               [AMD, Radeon, R5, M330]
# 1302                 [Intel, HD, Graphics]
# Name: Gpu, Length: 1303, dtype: object

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df=df[df['Gpu']!='ARM']

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName                 Cpu   Ram  \
# 0              Ultrabook       Intel Core i5   8GB
# 1              Ultrabook       Intel Core i5   8GB
# 2               Notebook       Intel Core i5   8GB
# 3              Ultrabook       Intel Core i7  16GB
# 4              Ultrabook       Intel Core i5   8GB
# ...                  ...                 ...   ...
# 1298  2 in 1 Convertible       Intel Core i7   4GB
# 1299  2 in 1 Convertible       Intel Core i7  16GB
# 1300            Notebook  Intel Celeron Dual   2GB
# 1301            Notebook       Intel Core i7   6GB
# 1302            Notebook  Intel Celeron Dual   4GB
#
#                                Gpu       OpSys  Weight  Price_euros    PPI  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  227.0
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  128.0
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  141.0
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45  221.0
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60  227.0
# ...                            ...         ...     ...          ...    ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00  157.0
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00  276.0
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00  112.0
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00  100.0
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00  100.0
#
#       Touchscreen  IPS
# 0               0    1
# 1               0    0
# 2               0    0
# 3               0    1
# 4               0    1
# ...           ...  ...
# 1298            1    1
# 1299            1    1
# 1300            0    0
# 1301            0    0
# 1302            0    0
#
# [1303 rows x 13 columns]

# %%
sns.barplot(x=df['Gpu'],y=df['Price_euros'])
plt.xticks(rotation=90)
plt.show()

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def os(text):
  if text=="Windows 10" or text=="Windows 10 S":
    return "Windows"
  elif text=="Mac OS X" or text=="macOS":
    return "Mac"
  else:
    return "Other OS/Linux/No OS"

# %%
df['OpSys']=df['OpSys'].apply(os)

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows                 1080
# Other OS/Linux/No OS     202
# Mac                       21
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OpSys'>

# %%
sns.barplot(x=df['OpSys'],y=df['Price_euros'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Weight']=df['Weight'].apply(lambda x:x.replace("kg","")).astype('float')

# %%
df['Weight'].value_counts()
# Out:
# Weight
# 2.20    126
# 2.10     58
# 2.00     45
# 2.40     44
# 2.30     41
#        ...
# 4.50      1
# 1.14      1
# 3.80      1
# 3.25      1
# 2.34      1
# Name: count, Length: 171, dtype: int64

# %%
sns.displot(x=df['Weight'],kde=True)

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1111
# 1     192
# Name: count, dtype: int64

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price_euros'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['IPS'],y=df['Price_euros'])
plt.xticks(rotation=90)
plt.show()

# %%
df['PPI'].value_counts()
# Out:
# PPI
# 141.0    430
# 100.0    212
# 157.0    133
# 127.0    131
# 166.0    110
# 112.0     45
# 135.0     31
# 276.0     27
# 176.0     25
# 282.0     23
# 106.0     22
# 210.0     18
# 125.0      9
# 118.0      8
# 331.0      7
# 255.0      7
# 227.0      6
# 201.0      6
# 226.0      6
# 221.0      6
# 235.0      5
# 147.0      4
# 352.0      4
# 224.0      4
# 158.0      4
# 128.0      4
# 317.0      2
# 200.0      2
# 91.0       2
# 170.0      2
# 190.0      2
# 120.0      1
# 111.0      1
# 267.0      1
# 162.0      1
# 108.0      1
# 195.0      1
# Name: count, dtype: int64

# %%
sns.displot(x=df['PPI'],kde=True)

# %%
X=df.drop(columns=['Price_euros'])
y=np.log(df['Price_euros'])

# %%
X_train:1084
y_train: 1084

X_test: 191
y_test: 191

# %%
df.drop_duplicates(inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
X_train.shape
# Out:
# (977, 12)

# %%
X_test.shape
# Out:
# (326, 12)

# %%
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline as pipe
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.linear_model import LinearRegression,Ridge,Lasso

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
# !pip install streamlit --quiet

# %%
# %%writefile app.py
import streamlit as st
import pickle
import numpy as np

#Import the model
df=pickle.load(open('df.pkl','rb'))
pipe=pickle.load(open('pipe.pkl','rb'))

st.title("Laptop Price Predictor")
company=st.selectbox("Brand",df['Company'].unique(),index=4)
type=st.selectbox("Type",df['TypeName'].unique(),index=1)
cpu=st.selectbox("Cpu",df['Cpu'].unique(),index=0)
ram=st.selectbox("Ram",[2,4,6,8,12,16,24,32,64,128],index=3)
gpu=st.selectbox("Gpu",df['Gpu'].unique(),index=0)
os=st.selectbox("Os",df['OpSys'].unique(),index=2)
weight=st.number_input("Weight(in kg)",min_value=0.6,max_value=4.7,value=2.0,step=0.1)
touchscreen=st.selectbox("Touchscreen",['Yes','No'])
ips=st.selectbox("ips",['Yes','No'])
screen_size=st.number_input("Screen size(in Inches),calculated diagonally",
min_value=10.0,max_value=18.5,value=15.6,step=0.1)
resolution=st.selectbox("Screen Resolution",['2560x1600', '1440x900', '1920x1080', '2880x1800', '1366x768', '2304x1440',
 '3200x1800', '1920x1200', '2256x1504', '3840x2160', '2160x1440', '2560x1440', '1600x900', '2736x1824', '2400x1600'],index=2)

if st.button("PREDICT"):
  ppi=None
  if(touchscreen=='Yes'):
    touchscreen=1
  else:
    touchscreen=0
  if (ips=='Yes'):
    ips=1
  else:
    ips=0
  X_res=int(resolution.split('x')[0])
  Y_res=int(resolution.split('x')[1])
  ppi=((X_res**2)+(Y_res**2))**0.5/screen_size
  query=np.array([[company,type,cpu,ram,gpu,os,weight,touchscreen,ips,ppi]])
  op=np.exp(pipe.predict(query))
  st.subheader("The predicted price of the laptop for the above configuration is "+str(round(op[0]))+" pounds.")
# Out:
# Overwriting app.py

# %%
df['OpSys'].unique()
# Out:
# array(['Mac', 'Other OS/Linux/No OS', 'Windows'], dtype=object)

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.227.3.119:8501
#
# your url is: https://chubby-cups-kick.loca.lt
# 2024-08-31 07:04:02.504 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/exec_code.py", line 88, in exec_func_with_error_handling
#     result = func()
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 590, in code_to_exec
#     exec(code, module.__dict__)
#   File "/content/app.py", line 38, in <module>
#     op=np.exp(pipe.predict(query))
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_available_if.py", line 40, in out
#     if not self.check(args[0]):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 44, in check
#     getattr(self._final_estimator, attr)
# AttributeError: 'numpy.ndarray' object has no attribute '_final_estimator'
# 2024-08-31 07:04:03.298 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/exec_code.py", line 88, in exec_func_with_error_handling
#     result = func()
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 590, in code_to_exec
#     exec(code, module.__dict__)
#   File "/content/app.py", line 38, in <module>
#     op=np.exp(pipe.predict(query))
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_available_if.py", line 40, in out
#     if not self.check(args[0]):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 44, in check
#     getattr(self._final_estimator, attr)
# AttributeError: 'numpy.ndarray' object has no attribute '_final_estimator'
#   Stopping...
# ^C
